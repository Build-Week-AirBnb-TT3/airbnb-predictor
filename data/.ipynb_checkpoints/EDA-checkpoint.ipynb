# %%
### imports
# to get zip files into csv 
import gzip
import csv
import json
# pandas 
import pandas as pd
import string
from distutils.util import strtobool

# %%
# converting .csv.gz files to dataframe 

asheville = pd.read_csv('ashevillelisting.csv.gz', compression='gzip', header=0,    sep=',', quotechar='"', error_bad_lines=False)
austin = pd.read_csv('austinlisting.csv.gz', compression='gzip', header=0,    sep=',', quotechar='"', error_bad_lines=False)
boston = pd.read_csv('bostonlisting.csv.gz', compression='gzip', header=0,    sep=',', quotechar='"', error_bad_lines=False)
broward = pd.read_csv('browardcountylisting.csv.gz', compression='gzip', header=0,    sep=',', quotechar='"', error_bad_lines=False)
cambridge = pd.read_csv('cambridgelisting.csv.gz', compression='gzip', header=0,    sep=',', quotechar='"', error_bad_lines=False)

chicago = pd.read_csv('chicagolisting.csv.gz', compression='gzip', header=0,    sep=',', quotechar='"', error_bad_lines=False)
clarkcounty = pd.read_csv('clarkcountylisting.csv.gz', compression='gzip', header=0,    sep=',', quotechar='"', error_bad_lines=False)
columbus = pd.read_csv('columbuslisting.csv.gz', compression='gzip', header=0,    sep=',', quotechar='"', error_bad_lines=False)
dc = pd.read_csv('dclisting.csv.gz', compression='gzip', header=0,    sep=',', quotechar='"', error_bad_lines=False)
denver = pd.read_csv('denverlisting.csv.gz', compression='gzip', header=0,    sep=',', quotechar='"', error_bad_lines=False)

hawaii = pd.read_csv('hawaiilisting.csv.gz', compression='gzip', header=0,    sep=',', quotechar='"', error_bad_lines=False)
jerseycity = pd.read_csv('jerseycitylisting.csv.gz', compression='gzip', header=0,    sep=',', quotechar='"', error_bad_lines=False)
#TODO I typoed losangeleslistingcsv.gz ---- rename it with a dot and then you can run it
losangeles = pd.read_csv('losangeleslisting.csv.gz', compression='gzip', header=0,    sep=',', quotechar='"', error_bad_lines=False)
nashville = pd.read_csv('nashvillelisting.csv.gz', compression='gzip', header=0,    sep=',', quotechar='"', error_bad_lines=False)
neworleans = pd.read_csv('neworleanslisting.csv.gz', compression='gzip', header=0,    sep=',', quotechar='"', error_bad_lines=False)

nyc = pd.read_csv('nyclisting.csv.gz', compression='gzip', header=0,    sep=',', quotechar='"', error_bad_lines=False)
oakland = pd.read_csv('oaklandlisting.csv.gz', compression='gzip', header=0,    sep=',', quotechar='"', error_bad_lines=False)
pacificgrove = pd.read_csv('pacificfgrovelisting.csv.gz', compression='gzip', header=0,    sep=',', quotechar='"', error_bad_lines=False)
portland = pd.read_csv('portlandlisting.csv.gz', compression='gzip', header=0,    sep=',', quotechar='"', error_bad_lines=False)
ri = pd.read_csv('rhodeislandlisting.csv.gz', compression='gzip', header=0,    sep=',', quotechar='"', error_bad_lines=False)

salem = pd.read_csv('salemlisting.csv.gz', compression='gzip', header=0,    sep=',', quotechar='"', error_bad_lines=False)
sandiego = pd.read_csv('sandiegolisting.csv.gz', compression='gzip', header=0,    sep=',', quotechar='"', error_bad_lines=False)
sanfran = pd.read_csv('sanfranciscolisting.csv.gz', compression='gzip', header=0,    sep=',', quotechar='"', error_bad_lines=False)
sanmateo = pd.read_csv('sanmateocountylisting.csv.gz', compression='gzip', header=0,    sep=',', quotechar='"', error_bad_lines=False)
#df25 = pd.read_csv('santaclaracountylisting.csv.gz', compression='gzip', header=0,    sep=',', quotechar='"', error_bad_lines=False)

santacruz = pd.read_csv('santacruzlisting.csv.gz', compression='gzip', header=0,    sep=',', quotechar='"', error_bad_lines=False)
seattle = pd.read_csv('seattlelisting.csv.gz', compression='gzip', header=0,    sep=',', quotechar='"', error_bad_lines=False)
twincities = pd.read_csv('twincitieslisting.csv.gz', compression='gzip', header=0,    sep=',', quotechar='"', error_bad_lines=False)

# %%
df1.shape, df2.shape, df3.shape, df4.shape, df5.shape
# Out:
# ((2172, 74), (4513, 74), (694, 74), (6383, 74), (3236, 74))

# %%
asheville['location'] = 'Asheville'
austin['location'] = 'Austin'
boston['location'] = 'Boston'
broward['location'] = 'Broward County'
cambridge['location'] = 'Cambridge'
chicago['location'] = 'Chicago'
clarkcounty['location'] = 'Clark County'
columbus['location'] = 'Columbus'
dc['location'] = 'Washington, D.C.'
denver['location'] = 'Denver'
hawaii['location'] = 'Anywhere in Hawaii'
jerseycity['location'] = 'Jersey City'
losangeles['location'] = 'Los Angeles'
nashville['location'] = 'Nashville'
neworleans['location'] = 'New Orleans'
nyc['location'] = 'New York City'
oakland['location'] = 'Oakland'
pacificgrove['location'] = 'Pacific Grove'
portland['location'] = 'Portland'
ri['location'] = 'Anywhere in Rhode Island'
salem['location'] = 'Salem'
sandiego['location'] = 'San Diego'
sanfran['location'] = 'San Francisco'
sanmateo['location'] = 'San Mateo County'
santacruz['location'] = 'Santa Cruz County'
seattle['location'] = 'Seattle'
twincities['location'] = 'Twin Cities'

# %%
asheville['state'] = 'NC'
austin['state'] = 'TX'
boston['state'] = 'MA'
broward['state'] = 'FL'
cambridge['state'] = 'MA'
chicago['state'] = 'IL'
clarkcounty['state'] = 'NV'
columbus['state'] = 'OH'
dc['state'] = 'DC'
denver['state'] = 'CO'
hawaii['state'] = 'HI'
jerseycity['state'] =  'NJ'
losangeles['state'] = 'CA'
nashville['state'] = 'TN'
neworleans['state'] = 'LA'
nyc['state'] = 'NY'
oakland['state'] = 'CA'
pacificgrove['state'] = 'CA'
portland['state'] = 'OR'
ri['state'] = 'RI'
salem['state'] = 'OR'
sandiego['state'] = 'CA'
sanfran['state'] = 'CA'
sanmateo['state'] = 'CA'
santacruz['state'] = 'CA'
seattle['state'] = 'WA'
twincities['state'] = 'MN'

# %%
# concat all the dfs 
df = pd.concat([asheville,austin,boston,broward,cambridge,
                chicago,clarkcounty,columbus,dc,denver,
                hawaii,jerseycity,losangeles,nashville,neworleans,
                nyc,oakland,pacificgrove,portland,ri,
                salem,sandiego,sanfran,sanmateo,
                santacruz,seattle,twincities
                ])

# %%
df.shape
# Out:
# (184835, 76)

# %%
# df.to_csv('listings.csv', 
#           index=False)

# %%
df.set_index('id', inplace=True)

# %%
df.head()
# Out:
#                                 listing_url       scrape_id last_scraped  \
# id
# 108061  https://www.airbnb.com/rooms/108061  20201108173816   2020-11-08
# 155305  https://www.airbnb.com/rooms/155305  20201108173816   2020-11-08
# 156926  https://www.airbnb.com/rooms/156926  20201108173816   2020-11-08
# 160594  https://www.airbnb.com/rooms/160594  20201108173816   2020-11-08
# 209068  https://www.airbnb.com/rooms/209068  20201108173816   2020-11-08
#
#                                                      name  \
# id
# 108061  Walk to stores/parks/downtown. Fenced yard/Pet...
# 155305                 Cottage! BonPaul + Sharky's Hostel
# 156926             Mixed Dorm "Top Bunk #1" at BPS Hostel
# 160594                                Historic Grove Park
# 209068                                    Terrace Cottage
#
#                                               description  \
# id
# 108061  Walk to town in ten minutes! Monthly rental in...
# 155305  <b>The space</b><br />Private cottage located ...
# 156926  This is a top bunk in the mixed dorm room<br /...
# 160594  Come enjoy the beautiful Grove Park neighborho...
# 209068  Located in one of Asheville's oldest historic ...
#
#                                     neighborhood_overview  \
# id
# 108061  I love my neighborhood! Its friendly, easy-goi...
# 155305  We are within easy walk of pubs, breweries, mu...
# 156926                                                NaN
# 160594                                                NaN
# 209068  Our beautiful historic district close to downt...
#
#                                               picture_url  host_id  \
# id
# 108061  https://a0.muscache.com/pictures/41011975/0cdf...   320564
# 155305  https://a0.muscache.com/pictures/8880711/cf38d...   746673
# 156926  https://a0.muscache.com/pictures/98f4e655-c4d6...   746673
# 160594  https://a0.muscache.com/pictures/92433837/d340...   769252
# 209068  https://a0.muscache.com/pictures/1829924/9f3bf...  1029919
#
#                                          host_url  host_name  host_since  \
# id
# 108061   https://www.airbnb.com/users/show/320564       Lisa  2010-12-16
# 155305   https://www.airbnb.com/users/show/746673    BonPaul  2011-06-26
# 156926   https://www.airbnb.com/users/show/746673    BonPaul  2011-06-26
# 160594   https://www.airbnb.com/users/show/769252  Elizabeth  2011-07-02
# 209068  https://www.airbnb.com/users/show/1029919      Kevin  2011-08-28
#
#                                    host_location  \
# id
# 108061  Asheville, North Carolina, United States
# 155305  Asheville, North Carolina, United States
# 156926  Asheville, North Carolina, United States
# 160594  Asheville, North Carolina, United States
# 209068  Asheville, North Carolina, United States
#
#                                                host_about  host_response_time  \
# id
# 108061  I am a long time resident of Asheville and am ...        within a day
# 155305  We operate two traveler's hostels located in H...      within an hour
# 156926  We operate two traveler's hostels located in H...      within an hour
# 160594  We love having guests and sharing a piece of h...  a few days or more
# 209068  Welcome to Terrace Cottage!\r\n\r\nFor fifteen...  within a few hours
#
#        host_response_rate host_acceptance_rate host_is_superhost  \
# id
# 108061                90%                  25%                 f
# 155305               100%                 100%                 t
# 156926               100%                 100%                 t
# 160594                 0%                  NaN                 f
# 209068               100%                  60%                 f
#
#                                        host_thumbnail_url  \
# id
# 108061  https://a0.muscache.com/im/users/320564/profil...
# 155305  https://a0.muscache.com/im/users/746673/profil...
# 156926  https://a0.muscache.com/im/users/746673/profil...
# 160594  https://a0.muscache.com/im/users/769252/profil...
# 209068  https://a0.muscache.com/im/users/1029919/profi...
#
#                                          host_picture_url host_neighbourhood  \
# id
# 108061  https://a0.muscache.com/im/users/320564/profil...                NaN
# 155305  https://a0.muscache.com/im/users/746673/profil...                NaN
# 156926  https://a0.muscache.com/im/users/746673/profil...                NaN
# 160594  https://a0.muscache.com/im/users/769252/profil...                NaN
# 209068  https://a0.muscache.com/im/users/1029919/profi...                NaN
#
#         host_listings_count  host_total_listings_count  \
# id
# 108061                  2.0                        2.0
# 155305                  7.0                        7.0
# 156926                  7.0                        7.0
# 160594                  1.0                        1.0
# 209068                  1.0                        1.0
#
#                                        host_verifications  \
# id
# 108061  ['email', 'phone', 'facebook', 'reviews', 'off...
# 155305  ['email', 'phone', 'facebook', 'reviews', 'off...
# 156926  ['email', 'phone', 'facebook', 'reviews', 'off...
# 160594  ['email', 'phone', 'reviews', 'kba', 'work_ema...
# 209068  ['email', 'phone', 'reviews', 'offline_governm...
#
#        host_has_profile_pic host_identity_verified  \
# id
# 108061                    t                      t
# 155305                    t                      t
# 156926                    t                      t
# 160594                    t                      f
# 209068                    t                      t
#
#                                    neighbourhood neighbourhood_cleansed  \
# id
# 108061  Asheville, North Carolina, United States                  28801
# 155305  Asheville, North Carolina, United States                  28806
# 156926                                       NaN                  28806
# 160594                                       NaN                  28801
# 209068  Asheville, North Carolina, United States                  28804
#
#        neighbourhood_group_cleansed  latitude  longitude  \
# id
# 108061                          NaN  35.60670  -82.55563
# 155305                          NaN  35.57864  -82.59578
# 156926                          NaN  35.57864  -82.59578
# 160594                          NaN  35.61442  -82.54127
# 209068                          NaN  35.61856  -82.55276
#
#                 property_type        room_type  accommodates  bathrooms  \
# id
# 108061       Entire apartment  Entire home/apt             2        NaN
# 155305      Entire guesthouse  Entire home/apt             2        NaN
# 156926  Shared room in hostel      Shared room             1        NaN
# 160594  Private room in house     Private room             2        NaN
# 209068     Entire guest suite  Entire home/apt             4        NaN
#
#           bathrooms_text  bedrooms  beds  \
# id
# 108061            1 bath       1.0   1.0
# 155305            1 bath       1.0   1.0
# 156926  2.5 shared baths       1.0   6.0
# 160594            1 bath       1.0   1.0
# 209068            1 bath       1.0   2.0
#
#                                                 amenities    price  \
# id
# 108061  ["Hot water", "Bed linens", "Dryer", "Host gre...   $82.00
# 155305  ["Hot water", "Free street parking", "Refriger...   $92.00
# 156926  ["Air conditioning", "Hot water", "Heating", "...   $30.00
# 160594  ["Lock on bedroom door", "Heating", "Kitchen",...  $125.00
# 209068  ["Hot water", "Dryer", "Refrigerator", "Hair d...  $134.00
#
#         minimum_nights  maximum_nights  minimum_minimum_nights  \
# id
# 108061              30             365                    30.0
# 155305               1              31                     1.0
# 156926               1             365                     1.0
# 160594              30            1125                    30.0
# 209068               7             360                     7.0
#
#         maximum_minimum_nights  minimum_maximum_nights  \
# id
# 108061                    30.0                  1125.0
# 155305                     1.0                     7.0
# 156926                     1.0                     1.0
# 160594                    30.0                  1125.0
# 209068                     7.0                   360.0
#
#         maximum_maximum_nights  minimum_nights_avg_ntm  \
# id
# 108061                  1125.0                    30.0
# 155305                     7.0                     1.0
# 156926                     4.0                     1.0
# 160594                  1125.0                    30.0
# 209068                   360.0                     7.0
#
#         maximum_nights_avg_ntm  calendar_updated has_availability  \
# id
# 108061                  1125.0               NaN                t
# 155305                     7.0               NaN                t
# 156926                     4.0               NaN                t
# 160594                  1125.0               NaN                t
# 209068                   360.0               NaN                t
#
#         availability_30  availability_60  availability_90  availability_365  \
# id
# 108061                7               18               18               149
# 155305               12               41               71               346
# 156926                0                0                0                 0
# 160594               30               60               90               365
# 209068                4               34               64               339
#
#        calendar_last_scraped  number_of_reviews  number_of_reviews_ltm  \
# id
# 108061            2020-11-08                 89                      1
# 155305            2020-11-08                275                     50
# 156926            2020-11-08                290                     15
# 160594            2020-11-08                 58                      0
# 209068            2020-11-08                 56                      3
#
#         number_of_reviews_l30d first_review last_review  review_scores_rating  \
# id
# 108061                       0   2011-09-21  2019-11-30                  90.0
# 155305                       7   2011-07-31  2020-11-04                  91.0
# 156926                       3   2012-05-25  2020-11-01                  94.0
# 160594                       0   2011-08-07  2015-10-19                  99.0
# 209068                       0   2011-09-19  2020-09-25                  97.0
#
#         review_scores_accuracy  review_scores_cleanliness  \
# id
# 108061                     9.0                        9.0
# 155305                    10.0                        9.0
# 156926                    10.0                        9.0
# 160594                    10.0                       10.0
# 209068                    10.0                       10.0
#
#         review_scores_checkin  review_scores_communication  \
# id
# 108061                   10.0                         10.0
# 155305                   10.0                         10.0
# 156926                   10.0                          9.0
# 160594                   10.0                         10.0
# 209068                   10.0                         10.0
#
#         review_scores_location  review_scores_value license instant_bookable  \
# id
# 108061                    10.0                  9.0     NaN                f
# 155305                    10.0                 10.0     NaN                t
# 156926                    10.0                 10.0     NaN                t
# 160594                    10.0                 10.0     NaN                f
# 209068                    10.0                 10.0     NaN                f
#
#         calculated_host_listings_count  \
# id
# 108061                               2
# 155305                               6
# 156926                               6
# 160594                               1
# 209068                               1
#
#         calculated_host_listings_count_entire_homes  \
# id
# 108061                                            2
# 155305                                            1
# 156926                                            1
# 160594                                            0
# 209068                                            1
#
#         calculated_host_listings_count_private_rooms  \
# id
# 108061                                             0
# 155305                                             1
# 156926                                             1
# 160594                                             1
# 209068                                             0
#
#         calculated_host_listings_count_shared_rooms  reviews_per_month  \
# id
# 108061                                            0               0.80
# 155305                                            4               2.43
# 156926                                            4               2.82
# 160594                                            0               0.51
# 209068                                            0               0.50
#
#          location state
# id
# 108061  Asheville    NC
# 155305  Asheville    NC
# 156926  Asheville    NC
# 160594  Asheville    NC
# 209068  Asheville    NC

# %%
df = df.copy()

# %%
df['state'].value_counts()
# Out:
# CA    53499
# NY    36923
# HI    21623
# MA     9619
# NV     9156
# DC     7440
# IL     6383
# LA     6179
# TN     5945
# TX     4513
# WA     4335
# MN     3910
# OR     3671
# CO     3153
# RI     3035
# NC     2172
# NJ     1428
# OH     1157
# FL      694
# Name: state, dtype: int64

# %%
pd.set_option('display.max_columns', None)

# %%
df.head()
# Out:
#                                 listing_url       scrape_id last_scraped  \
# id
# 108061  https://www.airbnb.com/rooms/108061  20201108173816   2020-11-08
# 155305  https://www.airbnb.com/rooms/155305  20201108173816   2020-11-08
# 156926  https://www.airbnb.com/rooms/156926  20201108173816   2020-11-08
# 160594  https://www.airbnb.com/rooms/160594  20201108173816   2020-11-08
# 209068  https://www.airbnb.com/rooms/209068  20201108173816   2020-11-08
#
#                                                      name  \
# id
# 108061  Walk to stores/parks/downtown. Fenced yard/Pet...
# 155305                 Cottage! BonPaul + Sharky's Hostel
# 156926             Mixed Dorm "Top Bunk #1" at BPS Hostel
# 160594                                Historic Grove Park
# 209068                                    Terrace Cottage
#
#                                               description  \
# id
# 108061  Walk to town in ten minutes! Monthly rental in...
# 155305  <b>The space</b><br />Private cottage located ...
# 156926  This is a top bunk in the mixed dorm room<br /...
# 160594  Come enjoy the beautiful Grove Park neighborho...
# 209068  Located in one of Asheville's oldest historic ...
#
#                                     neighborhood_overview  \
# id
# 108061  I love my neighborhood! Its friendly, easy-goi...
# 155305  We are within easy walk of pubs, breweries, mu...
# 156926                                                NaN
# 160594                                                NaN
# 209068  Our beautiful historic district close to downt...
#
#                                               picture_url  host_id  \
# id
# 108061  https://a0.muscache.com/pictures/41011975/0cdf...   320564
# 155305  https://a0.muscache.com/pictures/8880711/cf38d...   746673
# 156926  https://a0.muscache.com/pictures/98f4e655-c4d6...   746673
# 160594  https://a0.muscache.com/pictures/92433837/d340...   769252
# 209068  https://a0.muscache.com/pictures/1829924/9f3bf...  1029919
#
#                                          host_url  host_name  host_since  \
# id
# 108061   https://www.airbnb.com/users/show/320564       Lisa  2010-12-16
# 155305   https://www.airbnb.com/users/show/746673    BonPaul  2011-06-26
# 156926   https://www.airbnb.com/users/show/746673    BonPaul  2011-06-26
# 160594   https://www.airbnb.com/users/show/769252  Elizabeth  2011-07-02
# 209068  https://www.airbnb.com/users/show/1029919      Kevin  2011-08-28
#
#                                    host_location  \
# id
# 108061  Asheville, North Carolina, United States
# 155305  Asheville, North Carolina, United States
# 156926  Asheville, North Carolina, United States
# 160594  Asheville, North Carolina, United States
# 209068  Asheville, North Carolina, United States
#
#                                                host_about  host_response_time  \
# id
# 108061  I am a long time resident of Asheville and am ...        within a day
# 155305  We operate two traveler's hostels located in H...      within an hour
# 156926  We operate two traveler's hostels located in H...      within an hour
# 160594  We love having guests and sharing a piece of h...  a few days or more
# 209068  Welcome to Terrace Cottage!\r\n\r\nFor fifteen...  within a few hours
#
#        host_response_rate host_acceptance_rate host_is_superhost  \
# id
# 108061                90%                  25%                 f
# 155305               100%                 100%                 t
# 156926               100%                 100%                 t
# 160594                 0%                  NaN                 f
# 209068               100%                  60%                 f
#
#                                        host_thumbnail_url  \
# id
# 108061  https://a0.muscache.com/im/users/320564/profil...
# 155305  https://a0.muscache.com/im/users/746673/profil...
# 156926  https://a0.muscache.com/im/users/746673/profil...
# 160594  https://a0.muscache.com/im/users/769252/profil...
# 209068  https://a0.muscache.com/im/users/1029919/profi...
#
#                                          host_picture_url host_neighbourhood  \
# id
# 108061  https://a0.muscache.com/im/users/320564/profil...                NaN
# 155305  https://a0.muscache.com/im/users/746673/profil...                NaN
# 156926  https://a0.muscache.com/im/users/746673/profil...                NaN
# 160594  https://a0.muscache.com/im/users/769252/profil...                NaN
# 209068  https://a0.muscache.com/im/users/1029919/profi...                NaN
#
#         host_listings_count  host_total_listings_count  \
# id
# 108061                  2.0                        2.0
# 155305                  7.0                        7.0
# 156926                  7.0                        7.0
# 160594                  1.0                        1.0
# 209068                  1.0                        1.0
#
#                                        host_verifications  \
# id
# 108061  ['email', 'phone', 'facebook', 'reviews', 'off...
# 155305  ['email', 'phone', 'facebook', 'reviews', 'off...
# 156926  ['email', 'phone', 'facebook', 'reviews', 'off...
# 160594  ['email', 'phone', 'reviews', 'kba', 'work_ema...
# 209068  ['email', 'phone', 'reviews', 'offline_governm...
#
#        host_has_profile_pic host_identity_verified  \
# id
# 108061                    t                      t
# 155305                    t                      t
# 156926                    t                      t
# 160594                    t                      f
# 209068                    t                      t
#
#                                    neighbourhood neighbourhood_cleansed  \
# id
# 108061  Asheville, North Carolina, United States                  28801
# 155305  Asheville, North Carolina, United States                  28806
# 156926                                       NaN                  28806
# 160594                                       NaN                  28801
# 209068  Asheville, North Carolina, United States                  28804
#
#        neighbourhood_group_cleansed  latitude  longitude  \
# id
# 108061                          NaN  35.60670  -82.55563
# 155305                          NaN  35.57864  -82.59578
# 156926                          NaN  35.57864  -82.59578
# 160594                          NaN  35.61442  -82.54127
# 209068                          NaN  35.61856  -82.55276
#
#                 property_type        room_type  accommodates  bathrooms  \
# id
# 108061       Entire apartment  Entire home/apt             2        NaN
# 155305      Entire guesthouse  Entire home/apt             2        NaN
# 156926  Shared room in hostel      Shared room             1        NaN
# 160594  Private room in house     Private room             2        NaN
# 209068     Entire guest suite  Entire home/apt             4        NaN
#
#           bathrooms_text  bedrooms  beds  \
# id
# 108061            1 bath       1.0   1.0
# 155305            1 bath       1.0   1.0
# 156926  2.5 shared baths       1.0   6.0
# 160594            1 bath       1.0   1.0
# 209068            1 bath       1.0   2.0
#
#                                                 amenities    price  \
# id
# 108061  ["Hot water", "Bed linens", "Dryer", "Host gre...   $82.00
# 155305  ["Hot water", "Free street parking", "Refriger...   $92.00
# 156926  ["Air conditioning", "Hot water", "Heating", "...   $30.00
# 160594  ["Lock on bedroom door", "Heating", "Kitchen",...  $125.00
# 209068  ["Hot water", "Dryer", "Refrigerator", "Hair d...  $134.00
#
#         minimum_nights  maximum_nights  minimum_minimum_nights  \
# id
# 108061              30             365                    30.0
# 155305               1              31                     1.0
# 156926               1             365                     1.0
# 160594              30            1125                    30.0
# 209068               7             360                     7.0
#
#         maximum_minimum_nights  minimum_maximum_nights  \
# id
# 108061                    30.0                  1125.0
# 155305                     1.0                     7.0
# 156926                     1.0                     1.0
# 160594                    30.0                  1125.0
# 209068                     7.0                   360.0
#
#         maximum_maximum_nights  minimum_nights_avg_ntm  \
# id
# 108061                  1125.0                    30.0
# 155305                     7.0                     1.0
# 156926                     4.0                     1.0
# 160594                  1125.0                    30.0
# 209068                   360.0                     7.0
#
#         maximum_nights_avg_ntm  calendar_updated has_availability  \
# id
# 108061                  1125.0               NaN                t
# 155305                     7.0               NaN                t
# 156926                     4.0               NaN                t
# 160594                  1125.0               NaN                t
# 209068                   360.0               NaN                t
#
#         availability_30  availability_60  availability_90  availability_365  \
# id
# 108061                7               18               18               149
# 155305               12               41               71               346
# 156926                0                0                0                 0
# 160594               30               60               90               365
# 209068                4               34               64               339
#
#        calendar_last_scraped  number_of_reviews  number_of_reviews_ltm  \
# id
# 108061            2020-11-08                 89                      1
# 155305            2020-11-08                275                     50
# 156926            2020-11-08                290                     15
# 160594            2020-11-08                 58                      0
# 209068            2020-11-08                 56                      3
#
#         number_of_reviews_l30d first_review last_review  review_scores_rating  \
# id
# 108061                       0   2011-09-21  2019-11-30                  90.0
# 155305                       7   2011-07-31  2020-11-04                  91.0
# 156926                       3   2012-05-25  2020-11-01                  94.0
# 160594                       0   2011-08-07  2015-10-19                  99.0
# 209068                       0   2011-09-19  2020-09-25                  97.0
#
#         review_scores_accuracy  review_scores_cleanliness  \
# id
# 108061                     9.0                        9.0
# 155305                    10.0                        9.0
# 156926                    10.0                        9.0
# 160594                    10.0                       10.0
# 209068                    10.0                       10.0
#
#         review_scores_checkin  review_scores_communication  \
# id
# 108061                   10.0                         10.0
# 155305                   10.0                         10.0
# 156926                   10.0                          9.0
# 160594                   10.0                         10.0
# 209068                   10.0                         10.0
#
#         review_scores_location  review_scores_value license instant_bookable  \
# id
# 108061                    10.0                  9.0     NaN                f
# 155305                    10.0                 10.0     NaN                t
# 156926                    10.0                 10.0     NaN                t
# 160594                    10.0                 10.0     NaN                f
# 209068                    10.0                 10.0     NaN                f
#
#         calculated_host_listings_count  \
# id
# 108061                               2
# 155305                               6
# 156926                               6
# 160594                               1
# 209068                               1
#
#         calculated_host_listings_count_entire_homes  \
# id
# 108061                                            2
# 155305                                            1
# 156926                                            1
# 160594                                            0
# 209068                                            1
#
#         calculated_host_listings_count_private_rooms  \
# id
# 108061                                             0
# 155305                                             1
# 156926                                             1
# 160594                                             1
# 209068                                             0
#
#         calculated_host_listings_count_shared_rooms  reviews_per_month
# id
# 108061                                            0               0.80
# 155305                                            4               2.43
# 156926                                            4               2.82
# 160594                                            0               0.51
# 209068                                            0               0.50

# %%
df = df.drop(['listing_url', 'scrape_id', 'picture_url', 'host_url', 
              'host_name', 'host_thumbnail_url','host_picture_url',
             'host_neighbourhood'], axis=1)

# %%
df.shape
# Out:
# (184835, 66)

# %%
df['license'].value_counts().head(20)
# Out:
# City registration pending                                                            5414
# Exempt: This listing is a licensed hotel, motel, or bed and breakfast                1106
# Exempt - This listing is a transient occupancy residential structure                 1011
# Exempt                                                                                761
# License not needed per OSTR                                                           653
# Exempt - This listing is a bed and breakfast                                          581
# Exempt - This listing is a hotel or motel                                             535
# 32+ Days Listing                                                                      338
# Exempt: This listing is a unit that has contracts with hospitals                      219
# Exempt: This listing is a unit used for furnished institutional or business stays     176
# Exempt: This listing is a hotel or motel                                              171
# City Registration Pending                                                             118
# Licensed Hotel                                                                        104
# Pending                                                                                86
# STR-OPLI-19-003325                                                                     83
# 2653280                                                                                70
# 2637056                                                                                60
# 32+days Listing                                                                        56
# Registered                                                                             48
# 365804.0                                                                               44
# Name: license, dtype: int64

# %%
df['license'].isnull().sum()
# Out:
# 132665

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 184835 entries, 108061 to 46340175
# Data columns (total 67 columns):
#  #   Column                                        Non-Null Count   Dtype
# ---  ------                                        --------------   -----
#  0   last_scraped                                  184835 non-null  object
#  1   name                                          184817 non-null  object
#  2   description                                   181011 non-null  object
#  3   neighborhood_overview                         123477 non-null  object
#  4   host_id                                       184835 non-null  int64
#  5   host_since                                    184810 non-null  object
#  6   host_location                                 184437 non-null  object
#  7   host_about                                    121082 non-null  object
#  8   host_response_time                            140265 non-null  object
#  9   host_response_rate                            140265 non-null  object
#  10  host_acceptance_rate                          153315 non-null  object
#  11  host_is_superhost                             184810 non-null  object
#  12  host_listings_count                           184810 non-null  float64
#  13  host_total_listings_count                     184810 non-null  float64
#  14  host_verifications                            184835 non-null  object
#  15  host_has_profile_pic                          184810 non-null  object
#  16  host_identity_verified                        184810 non-null  object
#  17  neighbourhood                                 123481 non-null  object
#  18  neighbourhood_cleansed                        184835 non-null  object
#  19  neighbourhood_group_cleansed                  97387 non-null   object
#  20  latitude                                      184835 non-null  float64
#  21  longitude                                     184835 non-null  float64
#  22  property_type                                 184835 non-null  object
#  23  room_type                                     184835 non-null  object
#  24  accommodates                                  184835 non-null  int64
#  25  bathrooms                                     0 non-null       float64
#  26  bathrooms_text                                184627 non-null  object
#  27  bedrooms                                      166653 non-null  float64
#  28  beds                                          183495 non-null  float64
#  29  amenities                                     184835 non-null  object
#  30  price                                         184835 non-null  object
#  31  minimum_nights                                184835 non-null  int64
#  32  maximum_nights                                184835 non-null  int64
#  33  minimum_minimum_nights                        184559 non-null  float64
#  34  maximum_minimum_nights                        184559 non-null  float64
#  35  minimum_maximum_nights                        184559 non-null  float64
#  36  maximum_maximum_nights                        184559 non-null  float64
#  37  minimum_nights_avg_ntm                        184559 non-null  float64
#  38  maximum_nights_avg_ntm                        184559 non-null  float64
#  39  calendar_updated                              0 non-null       float64
#  40  has_availability                              184835 non-null  object
#  41  availability_30                               184835 non-null  int64
#  42  availability_60                               184835 non-null  int64
#  43  availability_90                               184835 non-null  int64
#  44  availability_365                              184835 non-null  int64
#  45  calendar_last_scraped                         184835 non-null  object
#  46  number_of_reviews                             184835 non-null  int64
#  47  number_of_reviews_ltm                         184835 non-null  int64
#  48  number_of_reviews_l30d                        184835 non-null  int64
#  49  first_review                                  144475 non-null  object
#  50  last_review                                   144475 non-null  object
#  51  review_scores_rating                          142667 non-null  float64
#  52  review_scores_accuracy                        142192 non-null  float64
#  53  review_scores_cleanliness                     142207 non-null  float64
#  54  review_scores_checkin                         142151 non-null  float64
#  55  review_scores_communication                   142193 non-null  float64
#  56  review_scores_location                        142149 non-null  float64
#  57  review_scores_value                           142140 non-null  float64
#  58  license                                       52170 non-null   object
#  59  instant_bookable                              184835 non-null  object
#  60  calculated_host_listings_count                184835 non-null  int64
#  61  calculated_host_listings_count_entire_homes   184835 non-null  int64
#  62  calculated_host_listings_count_private_rooms  184835 non-null  int64
#  63  calculated_host_listings_count_shared_rooms   184835 non-null  int64
#  64  reviews_per_month                             144475 non-null  float64
#  65  location                                      184835 non-null  object
#  66  state                                         184835 non-null  object
# dtypes: float64(22), int64(15), object(30)
# memory usage: 95.9+ MB

# %%
df['bathrooms_text'].value_counts()
# Out:
# 1 bath            87018
# 2 baths           28839
# 1 shared bath     22352
# 1 private bath    13772
# 1.5 baths          6577
#                   ...
# 18 baths              1
# 15.5 baths            1
# 19 baths              1
# 21 baths              1
# 16 baths              1
# Name: bathrooms_text, Length: 65, dtype: int64

# %%
df['last_scraped'].describe()
# Out:
# count         184835
# unique            20
# top       2020-12-11
# freq           36863
# Name: last_scraped, dtype: object

# %%
df.shape
# Out:
# (184835, 67)

# %%
df['number_of_reviews_l30d'].describe()
# Out:
# count    184835.000000
# mean          0.596494
# std           1.516428
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max          80.000000
# Name: number_of_reviews_l30d, dtype: float64

# %%
142494/184835
# Out:
# 0.7709254199691616

# %%
df['number_of_reviews_l30d'].value_counts()
# Out:
# 0     142494
# 1      17049
# 2       9086
# 3       6205
# 4       3885
# 5       2401
# 6       1376
# 7        917
# 8        535
# 9        352
# 10       193
# 11       117
# 12        78
# 13        46
# 14        31
# 15        18
# 16        11
# 18         6
# 17         5
# 19         5
# 35         4
# 40         3
# 23         3
# 25         2
# 27         2
# 50         1
# 47         1
# 41         1
# 36         1
# 26         1
# 30         1
# 24         1
# 22         1
# 21         1
# 20         1
# 80         1
# Name: number_of_reviews_l30d, dtype: int64

# %%
df['reviews_per_month'].value_counts(dropna=False)
# Out:
# NaN      40360
# 1.00      2069
# 0.06      2050
# 0.02      2015
# 0.03      1976
#          ...
# 15.98        1
# 11.23        1
# 12.84        1
# 13.73        1
# 15.11        1
# Name: reviews_per_month, Length: 1225, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 184835 entries, 108061 to 46340175
# Data columns (total 67 columns):
#  #   Column                                        Non-Null Count   Dtype
# ---  ------                                        --------------   -----
#  0   last_scraped                                  184835 non-null  object
#  1   name                                          184817 non-null  object
#  2   description                                   181011 non-null  object
#  3   neighborhood_overview                         123477 non-null  object
#  4   host_id                                       184835 non-null  int64
#  5   host_since                                    184810 non-null  object
#  6   host_location                                 184437 non-null  object
#  7   host_about                                    121082 non-null  object
#  8   host_response_time                            140265 non-null  object
#  9   host_response_rate                            140265 non-null  object
#  10  host_acceptance_rate                          153315 non-null  object
#  11  host_is_superhost                             184810 non-null  object
#  12  host_listings_count                           184810 non-null  float64
#  13  host_total_listings_count                     184810 non-null  float64
#  14  host_verifications                            184835 non-null  object
#  15  host_has_profile_pic                          184810 non-null  object
#  16  host_identity_verified                        184810 non-null  object
#  17  neighbourhood                                 123481 non-null  object
#  18  neighbourhood_cleansed                        184835 non-null  object
#  19  neighbourhood_group_cleansed                  97387 non-null   object
#  20  latitude                                      184835 non-null  float64
#  21  longitude                                     184835 non-null  float64
#  22  property_type                                 184835 non-null  object
#  23  room_type                                     184835 non-null  object
#  24  accommodates                                  184835 non-null  int64
#  25  bathrooms                                     0 non-null       float64
#  26  bathrooms_text                                184627 non-null  object
#  27  bedrooms                                      166653 non-null  float64
#  28  beds                                          183495 non-null  float64
#  29  amenities                                     184835 non-null  object
#  30  price                                         184835 non-null  object
#  31  minimum_nights                                184835 non-null  int64
#  32  maximum_nights                                184835 non-null  int64
#  33  minimum_minimum_nights                        184559 non-null  float64
#  34  maximum_minimum_nights                        184559 non-null  float64
#  35  minimum_maximum_nights                        184559 non-null  float64
#  36  maximum_maximum_nights                        184559 non-null  float64
#  37  minimum_nights_avg_ntm                        184559 non-null  float64
#  38  maximum_nights_avg_ntm                        184559 non-null  float64
#  39  calendar_updated                              0 non-null       float64
#  40  has_availability                              184835 non-null  object
#  41  availability_30                               184835 non-null  int64
#  42  availability_60                               184835 non-null  int64
#  43  availability_90                               184835 non-null  int64
#  44  availability_365                              184835 non-null  int64
#  45  calendar_last_scraped                         184835 non-null  object
#  46  number_of_reviews                             184835 non-null  int64
#  47  number_of_reviews_ltm                         184835 non-null  int64
#  48  number_of_reviews_l30d                        184835 non-null  int64
#  49  first_review                                  144475 non-null  object
#  50  last_review                                   144475 non-null  object
#  51  review_scores_rating                          142667 non-null  float64
#  52  review_scores_accuracy                        142192 non-null  float64
#  53  review_scores_cleanliness                     142207 non-null  float64
#  54  review_scores_checkin                         142151 non-null  float64
#  55  review_scores_communication                   142193 non-null  float64
#  56  review_scores_location                        142149 non-null  float64
#  57  review_scores_value                           142140 non-null  float64
#  58  license                                       52170 non-null   object
#  59  instant_bookable                              184835 non-null  object
#  60  calculated_host_listings_count                184835 non-null  int64
#  61  calculated_host_listings_count_entire_homes   184835 non-null  int64
#  62  calculated_host_listings_count_private_rooms  184835 non-null  int64
#  63  calculated_host_listings_count_shared_rooms   184835 non-null  int64
#  64  reviews_per_month                             144475 non-null  float64
#  65  location                                      184835 non-null  object
#  66  state                                         184835 non-null  object
# dtypes: float64(22), int64(15), object(30)
# memory usage: 95.9+ MB

# %%
df = df.drop(['calculated_host_listings_count',
            'calculated_host_listings_count_entire_homes',
            'calculated_host_listings_count_private_rooms',
            'calculated_host_listings_count_shared_rooms',
            'first_review',
            'minimum_minimum_nights',
            'maximum_minimum_nights',
            'minimum_maximum_nights',
            'maximum_maximum_nights',
            'has_availability',
            'availability_30',
            'availability_60',
            'availability_90',
            'availability_365',
            'number_of_reviews_ltm',
            'number_of_reviews_l30d',
            'host_response_time',
            'host_response_rate',
            'host_acceptance_rate',
            'host_listings_count',
            'host_total_listings_count'],
            axis=1)

# %%
df.shape
# Out:
# (184835, 46)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 184835 entries, 108061 to 46340175
# Data columns (total 46 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   last_scraped                  184835 non-null  object
#  1   name                          184817 non-null  object
#  2   description                   181011 non-null  object
#  3   neighborhood_overview         123477 non-null  object
#  4   host_id                       184835 non-null  int64
#  5   host_since                    184810 non-null  object
#  6   host_location                 184437 non-null  object
#  7   host_about                    121082 non-null  object
#  8   host_is_superhost             184810 non-null  object
#  9   host_verifications            184835 non-null  object
#  10  host_has_profile_pic          184810 non-null  object
#  11  host_identity_verified        184810 non-null  object
#  12  neighbourhood                 123481 non-null  object
#  13  neighbourhood_cleansed        184835 non-null  object
#  14  neighbourhood_group_cleansed  97387 non-null   object
#  15  latitude                      184835 non-null  float64
#  16  longitude                     184835 non-null  float64
#  17  property_type                 184835 non-null  object
#  18  room_type                     184835 non-null  object
#  19  accommodates                  184835 non-null  int64
#  20  bathrooms                     0 non-null       float64
#  21  bathrooms_text                184627 non-null  object
#  22  bedrooms                      166653 non-null  float64
#  23  beds                          183495 non-null  float64
#  24  amenities                     184835 non-null  object
#  25  price                         184835 non-null  object
#  26  minimum_nights                184835 non-null  int64
#  27  maximum_nights                184835 non-null  int64
#  28  minimum_nights_avg_ntm        184559 non-null  float64
#  29  maximum_nights_avg_ntm        184559 non-null  float64
#  30  calendar_updated              0 non-null       float64
#  31  calendar_last_scraped         184835 non-null  object
#  32  number_of_reviews             184835 non-null  int64
#  33  last_review                   144475 non-null  object
#  34  review_scores_rating          142667 non-null  float64
#  35  review_scores_accuracy        142192 non-null  float64
#  36  review_scores_cleanliness     142207 non-null  float64
#  37  review_scores_checkin         142151 non-null  float64
#  38  review_scores_communication   142193 non-null  float64
#  39  review_scores_location        142149 non-null  float64
#  40  review_scores_value           142140 non-null  float64
#  41  license                       52170 non-null   object
#  42  instant_bookable              184835 non-null  object
#  43  reviews_per_month             144475 non-null  float64
#  44  location                      184835 non-null  object
#  45  state                         184835 non-null  object
# dtypes: float64(16), int64(5), object(25)
# memory usage: 66.3+ MB

# %%
df = df.drop(['calendar_updated', 'reviews_per_month',
             'neighbourhood', 'neighbourhood_cleansed', 
              'neighbourhood_group_cleansed',
             'latitude','longitude','license','name','neighborhood_overview',
             'host_about'], axis=1)

# %%
df['last_review'].dropna()
# Out:
# id
# 108061      2019-11-30
# 155305      2020-11-04
# 156926      2020-11-01
# 160594      2015-10-19
# 209068      2020-09-25
#                ...
# 45940570    2020-11-06
# 45971207    2020-10-31
# 45987750    2020-10-30
# 46012844    2020-11-09
# 46033762    2020-11-09
# Name: last_review, Length: 144475, dtype: object

# %%
df['last_scraped']
# Out:
# id
# 108061      2020-11-08
# 155305      2020-11-08
# 156926      2020-11-08
# 160594      2020-11-08
# 209068      2020-11-08
#                ...
# 46334120    2020-11-10
# 46336525    2020-11-10
# 46337415    2020-11-10
# 46337510    2020-11-10
# 46340175    2020-11-10
# Name: last_scraped, Length: 184835, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 184835 entries, 108061 to 46340175
# Data columns (total 35 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   last_scraped                 184835 non-null  object
#  1   description                  181011 non-null  object
#  2   host_id                      184835 non-null  int64
#  3   host_since                   184810 non-null  object
#  4   host_location                184437 non-null  object
#  5   host_is_superhost            184810 non-null  object
#  6   host_verifications           184835 non-null  object
#  7   host_has_profile_pic         184810 non-null  object
#  8   host_identity_verified       184810 non-null  object
#  9   property_type                184835 non-null  object
#  10  room_type                    184835 non-null  object
#  11  accommodates                 184835 non-null  int64
#  12  bathrooms                    0 non-null       float64
#  13  bathrooms_text               184627 non-null  object
#  14  bedrooms                     166653 non-null  float64
#  15  beds                         183495 non-null  float64
#  16  amenities                    184835 non-null  object
#  17  price                        184835 non-null  object
#  18  minimum_nights               184835 non-null  int64
#  19  maximum_nights               184835 non-null  int64
#  20  minimum_nights_avg_ntm       184559 non-null  float64
#  21  maximum_nights_avg_ntm       184559 non-null  float64
#  22  calendar_last_scraped        184835 non-null  object
#  23  number_of_reviews            184835 non-null  int64
#  24  last_review                  144475 non-null  object
#  25  review_scores_rating         142667 non-null  float64
#  26  review_scores_accuracy       142192 non-null  float64
#  27  review_scores_cleanliness    142207 non-null  float64
#  28  review_scores_checkin        142151 non-null  float64
#  29  review_scores_communication  142193 non-null  float64
#  30  review_scores_location       142149 non-null  float64
#  31  review_scores_value          142140 non-null  float64
#  32  instant_bookable             184835 non-null  object
#  33  location                     184835 non-null  object
#  34  state                        184835 non-null  object
# dtypes: float64(12), int64(5), object(18)
# memory usage: 50.8+ MB

# %%
df = df.drop(['host_id', 'host_since', 'host_verifications',
             'review_scores_rating','review_scores_accuracy',
             'review_scores_cleanliness','review_scores_checkin',
             'review_scores_communication','review_scores_location',
             'review_scores_value'], axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 184835 entries, 108061 to 46340175
# Data columns (total 25 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   last_scraped            184835 non-null  object
#  1   description             181011 non-null  object
#  2   host_location           184437 non-null  object
#  3   host_is_superhost       184810 non-null  object
#  4   host_has_profile_pic    184810 non-null  object
#  5   host_identity_verified  184810 non-null  object
#  6   property_type           184835 non-null  object
#  7   room_type               184835 non-null  object
#  8   accommodates            184835 non-null  int64
#  9   bathrooms               0 non-null       float64
#  10  bathrooms_text          184627 non-null  object
#  11  bedrooms                166653 non-null  float64
#  12  beds                    183495 non-null  float64
#  13  amenities               184835 non-null  object
#  14  price                   184835 non-null  object
#  15  minimum_nights          184835 non-null  int64
#  16  maximum_nights          184835 non-null  int64
#  17  minimum_nights_avg_ntm  184559 non-null  float64
#  18  maximum_nights_avg_ntm  184559 non-null  float64
#  19  calendar_last_scraped   184835 non-null  object
#  20  number_of_reviews       184835 non-null  int64
#  21  last_review             144475 non-null  object
#  22  instant_bookable        184835 non-null  object
#  23  location                184835 non-null  object
#  24  state                   184835 non-null  object
# dtypes: float64(5), int64(4), object(16)
# memory usage: 36.7+ MB

# %%
df['last_review'] = pd.to_datetime(df['last_review'])

# %%
df['last_scraped'] = pd.to_datetime(df['last_scraped'])

# %%
df['last_review_time'] = df['last_scraped'] - df['last_review']

# %%
max_days = pd.to_timedelta(91, unit='D')

# %%
df_recent = df[df['last_review_time'] < max_days]

# %%
df_recent.shape
# Out:
# (63779, 26)

# %%
df.shape
# Out:
# (184835, 26)

# %%
184835-63779
# Out:
# 121056

# %%
121056/184835
# Out:
# 0.6549408932290962

# %%
df_recent = df_recent.drop(['host_location',
                            'last_scraped',
                            'last_review',
                            'minimum_nights',
                            'maximum_nights',
                            'minimum_nights_avg_ntm',
                            'maximum_nights_avg_ntm',
                            'calendar_last_scraped'], axis=1)

# %%
df_recent.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 63779 entries, 155305 to 46033762
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   description             63143 non-null  object
#  1   host_is_superhost       63773 non-null  object
#  2   host_has_profile_pic    63773 non-null  object
#  3   host_identity_verified  63773 non-null  object
#  4   property_type           63779 non-null  object
#  5   room_type               63779 non-null  object
#  6   accommodates            63779 non-null  int64
#  7   bathrooms               0 non-null      float64
#  8   bathrooms_text          63766 non-null  object
#  9   bedrooms                57085 non-null  float64
#  10  beds                    63528 non-null  float64
#  11  amenities               63779 non-null  object
#  12  price                   63779 non-null  object
#  13  number_of_reviews       63779 non-null  int64
#  14  instant_bookable        63779 non-null  object
#  15  location                63779 non-null  object
#  16  state                   63779 non-null  object
#  17  last_review_time        63779 non-null  timedelta64[ns]
# dtypes: float64(3), int64(2), object(12), timedelta64[ns](1)
# memory usage: 9.2+ MB

# %%
df_recent['bathrooms_text'].
# Out:
# id
# 155305                1 bath
# 156926      2.5 shared baths
# 209068                1 bath
# 259576                1 bath
# 295496                1 bath
#                   ...
# 45940570       1 shared bath
# 45971207              1 bath
# 45987750       1 shared bath
# 46012844      1 private bath
# 46033762           3.5 baths
# Name: bathrooms_text, Length: 63779, dtype: object

# %%
df_recent['bathrooms'] = df_recent['bathrooms_text'].str.rstrip(string.ascii_letters)

# %%
df_recent['bathrooms']
# Out:
# id
# 155305               1
# 156926      2.5 shared
# 209068               1
# 259576               1
# 295496               1
#                ...
# 45940570      1 shared
# 45971207             1
# 45987750      1 shared
# 46012844     1 private
# 46033762           3.5
# Name: bathrooms, Length: 63779, dtype: object

# %%
df_recent['bathrooms'] = df_recent['bathrooms'].str.strip()

# %%
df_recent['bathrooms']
# Out:
# id
# 155305               1
# 156926      2.5 shared
# 209068               1
# 259576               1
# 295496               1
#                ...
# 45940570      1 shared
# 45971207             1
# 45987750      1 shared
# 46012844     1 private
# 46033762           3.5
# Name: bathrooms, Length: 63779, dtype: object

# %%
df_recent['bathrooms'] = df_recent['bathrooms'].str.rstrip(string.ascii_letters)

# %%
df_recent['bathrooms']
# Out:
# id
# 155305         1
# 156926      2.5
# 209068         1
# 259576         1
# 295496         1
#             ...
# 45940570      1
# 45971207       1
# 45987750      1
# 46012844      1
# 46033762     3.5
# Name: bathrooms, Length: 63779, dtype: object

# %%
df_recent['bathrooms'].value_counts(dropna=False)
# Out:
# 1                33056
# 2                 9589
# 1                 9476
# 2.5               2410
# 1.5               2324
# 3                 2076
# 2                 1130
# 3.5                947
# 1.5                857
# 4                  570
# 4.5                220
# 3                  213
# 2.5                142
# 5                  138
# 0                   82
# 0                   68
# 5.5                 66
# 4                   60
# 6                   51
# half-               49
# 7                   35
# 3.5                 31
# shared half-        30
# 8                   28
# 6.5                 27
# 5                   16
# NaN                 13
# 11                  10
# 7.5                  9
# 6                    9
# 11                   8
# 8.5                  7
# private half-        6
# 8                    6
# 10.5                 3
# 8.5                  3
# 9                    3
# 4.5                  2
# 10                   2
# 17                   2
# 7                    2
# 14                   1
# 9.5                  1
# 6.5                  1
# Name: bathrooms, dtype: int64

# %%
df_recent['bathrooms'] = df_recent['bathrooms'].str.lower()

# %%
df_recent = df_recent[df_recent['bathrooms'].notna()]

# %%
mask = df_recent['bathrooms'].str.contains('half')

# %%
mask
# Out:
# id
# 155305      False
# 156926      False
# 209068      False
# 259576      False
# 295496      False
#             ...
# 45940570    False
# 45971207    False
# 45987750    False
# 46012844    False
# 46033762    False
# Name: bathrooms, Length: 63779, dtype: object

# %%
df_recent['bathrooms'] = df_recent['bathrooms'].where(~mask, other=0.5)

# %%
df_recent['bathrooms'].value_counts()
# Out:
# 1       33056
# 2        9589
# 1        9476
# 2.5      2410
# 1.5      2324
# 3        2076
# 2        1130
# 3.5       947
# 1.5       857
# 4         570
# 4.5       220
# 3         213
# 2.5       142
# 5         138
# 0.5        85
# 0          82
# 0          68
# 5.5        66
# 4          60
# 6          51
# 7          35
# 3.5        31
# 8          28
# 6.5        27
# 5          16
# 11         10
# 7.5         9
# 6           9
# 11          8
# 8.5         7
# 8           6
# 9           3
# 10.5        3
# 8.5         3
# 7           2
# 10          2
# 17          2
# 4.5         2
# 9.5         1
# 6.5         1
# 14          1
# Name: bathrooms, dtype: int64

# %%
df_recent['bathrooms'] = df_recent['bathrooms'].astype(float)

# %%
df_recent.head()
# Out:
#                                               description host_is_superhost  \
# id
# 155305  <b>The space</b><br />Private cottage located ...                 t
# 156926  This is a top bunk in the mixed dorm room<br /...                 t
# 209068  Located in one of Asheville's oldest historic ...                 f
# 259576  Hello! We are a small community of like-minded...                 t
# 295496  <b>The space</b><br />Welcome to "Fern Street ...                 f
#
#        host_has_profile_pic host_identity_verified          property_type  \
# id
# 155305                    t                      t      Entire guesthouse
# 156926                    t                      t  Shared room in hostel
# 209068                    t                      t     Entire guest suite
# 259576                    t                      t       Entire apartment
# 295496                    t                      t       Entire apartment
#
#               room_type  accommodates  bathrooms    bathrooms_text  bedrooms  \
# id
# 155305  Entire home/apt             2        1.0            1 bath       1.0
# 156926      Shared room             1        2.5  2.5 shared baths       1.0
# 209068  Entire home/apt             4        1.0            1 bath       1.0
# 259576  Entire home/apt             2        1.0            1 bath       1.0
# 295496  Entire home/apt             2        1.0            1 bath       1.0
#
#         beds                                          amenities    price  \
# id
# 155305   1.0  ["Hot water", "Free street parking", "Refriger...   $92.00
# 156926   6.0  ["Air conditioning", "Hot water", "Heating", "...   $30.00
# 209068   2.0  ["Hot water", "Dryer", "Refrigerator", "Hair d...  $134.00
# 259576   1.0  ["Hot water", "Dryer", "Ceiling fan", "Refrige...   $71.00
# 295496   0.0  ["Patio or balcony", "Air conditioning", "Bed ...   $50.00
#
#         number_of_reviews instant_bookable   location state last_review_time
# id
# 155305                275                t  Asheville    NC           4 days
# 156926                290                t  Asheville    NC           7 days
# 209068                 56                f  Asheville    NC          44 days
# 259576                538                f  Asheville    NC           8 days
# 295496                 32                f  Asheville    NC          29 days

# %%
df_recent.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 63766 entries, 155305 to 46033762
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   description             63131 non-null  object
#  1   host_is_superhost       63760 non-null  object
#  2   host_has_profile_pic    63760 non-null  object
#  3   host_identity_verified  63760 non-null  object
#  4   property_type           63766 non-null  object
#  5   room_type               63766 non-null  object
#  6   accommodates            63766 non-null  int64
#  7   bathrooms               63766 non-null  float64
#  8   bathrooms_text          63766 non-null  object
#  9   bedrooms                57074 non-null  float64
#  10  beds                    63518 non-null  float64
#  11  amenities               63766 non-null  object
#  12  price                   63766 non-null  object
#  13  number_of_reviews       63766 non-null  int64
#  14  instant_bookable        63766 non-null  object
#  15  location                63766 non-null  object
#  16  state                   63766 non-null  object
#  17  last_review_time        63766 non-null  timedelta64[ns]
# dtypes: float64(3), int64(2), object(12), timedelta64[ns](1)
# memory usage: 9.2+ MB

# %%
df_recent.head()
# Out:
#                                               description host_is_superhost  \
# id
# 155305  <b>The space</b><br />Private cottage located ...                 t
# 156926  This is a top bunk in the mixed dorm room<br /...                 t
# 209068  Located in one of Asheville's oldest historic ...                 f
# 259576  Hello! We are a small community of like-minded...                 t
# 295496  <b>The space</b><br />Welcome to "Fern Street ...                 f
#
#        host_has_profile_pic host_identity_verified          property_type  \
# id
# 155305                    t                      t      Entire guesthouse
# 156926                    t                      t  Shared room in hostel
# 209068                    t                      t     Entire guest suite
# 259576                    t                      t       Entire apartment
# 295496                    t                      t       Entire apartment
#
#               room_type  accommodates  bathrooms    bathrooms_text  bedrooms  \
# id
# 155305  Entire home/apt             2        1.0            1 bath       1.0
# 156926      Shared room             1        2.5  2.5 shared baths       1.0
# 209068  Entire home/apt             4        1.0            1 bath       1.0
# 259576  Entire home/apt             2        1.0            1 bath       1.0
# 295496  Entire home/apt             2        1.0            1 bath       1.0
#
#         beds                                          amenities    price  \
# id
# 155305   1.0  ["Hot water", "Free street parking", "Refriger...   $92.00
# 156926   6.0  ["Air conditioning", "Hot water", "Heating", "...   $30.00
# 209068   2.0  ["Hot water", "Dryer", "Refrigerator", "Hair d...  $134.00
# 259576   1.0  ["Hot water", "Dryer", "Ceiling fan", "Refrige...   $71.00
# 295496   0.0  ["Patio or balcony", "Air conditioning", "Bed ...   $50.00
#
#         number_of_reviews instant_bookable   location state last_review_time
# id
# 155305                275                t  Asheville    NC           4 days
# 156926                290                t  Asheville    NC           7 days
# 209068                 56                f  Asheville    NC          44 days
# 259576                538                f  Asheville    NC           8 days
# 295496                 32                f  Asheville    NC          29 days

# %%
df_recent = df_recent.drop(['bathrooms_text'], axis=1)

# %%
df_recent['price'] = df_recent['price'].str.strip('$')

# %%
df_recent['price'] = df_recent['price'].str.replace(',','')

# %%
df_recent['price'] = df_recent['price'].astype(float)

# %%
df_recent.head(10)
# Out:
#                                               description host_is_superhost  \
# id
# 155305  <b>The space</b><br />Private cottage located ...                 t
# 156926  This is a top bunk in the mixed dorm room<br /...                 t
# 209068  Located in one of Asheville's oldest historic ...                 f
# 259576  Hello! We are a small community of like-minded...                 t
# 295496  <b>The space</b><br />Welcome to "Fern Street ...                 f
# 353092  Sweet homestay space has private entrance, sma...                 t
# 427497  Escape to our beautifully furnished luxurious ...                 f
# 436476  ***We are taking extra steps to make sure our ...                 t
# 483384  The artist/owner built cottage is a quiet sanc...                 t
# 495111  Private room. King bed. Private full bathroom....                 t
#
#        host_has_profile_pic host_identity_verified          property_type  \
# id
# 155305                    t                      t      Entire guesthouse
# 156926                    t                      t  Shared room in hostel
# 209068                    t                      t     Entire guest suite
# 259576                    t                      t       Entire apartment
# 295496                    t                      t       Entire apartment
# 353092                    t                      t     Entire guest suite
# 427497                    t                      f     Entire guest suite
# 436476                    t                      t     Entire guest suite
# 483384                    t                      t         Entire cottage
# 495111                    t                      t  Private room in house
#
#               room_type  accommodates  bathrooms  bedrooms  beds  \
# id
# 155305  Entire home/apt             2        1.0       1.0   1.0
# 156926      Shared room             1        2.5       1.0   6.0
# 209068  Entire home/apt             4        1.0       1.0   2.0
# 259576  Entire home/apt             2        1.0       1.0   1.0
# 295496  Entire home/apt             2        1.0       1.0   0.0
# 353092  Entire home/apt             4        1.0       1.0   3.0
# 427497  Entire home/apt             2        1.0       1.0   1.0
# 436476  Entire home/apt             3        1.5       1.0   1.0
# 483384  Entire home/apt             3        1.0       1.0   1.0
# 495111     Private room             2        1.0       NaN   1.0
#
#                                                 amenities  price  \
# id
# 155305  ["Hot water", "Free street parking", "Refriger...   92.0
# 156926  ["Air conditioning", "Hot water", "Heating", "...   30.0
# 209068  ["Hot water", "Dryer", "Refrigerator", "Hair d...  134.0
# 259576  ["Hot water", "Dryer", "Ceiling fan", "Refrige...   71.0
# 295496  ["Patio or balcony", "Air conditioning", "Bed ...   50.0
# 353092  ["Hot water", "Bed linens", "Dryer", "Shower g...   78.0
# 427497  ["Hot water", "Dryer", "Host greets you", "Hai...  125.0
# 436476  ["Hot water", "Bed linens", "Dryer", "Shower g...  114.0
# 483384  ["Bedroom comforts", "Air conditioning", "Bath...  133.0
# 495111  ["Hot water", "Bed linens", "Conditioner", "La...   93.0
#
#         number_of_reviews instant_bookable   location state last_review_time
# id
# 155305                275                t  Asheville    NC           4 days
# 156926                290                t  Asheville    NC           7 days
# 209068                 56                f  Asheville    NC          44 days
# 259576                538                f  Asheville    NC           8 days
# 295496                 32                f  Asheville    NC          29 days
# 353092                500                f  Asheville    NC          12 days
# 427497                 41                f  Asheville    NC          13 days
# 436476                297                t  Asheville    NC           8 days
# 483384                479                t  Asheville    NC           8 days
# 495111                344                t  Asheville    NC           6 days

# %%
df_recent['number_of_amenities'] = df_recent['amenities'].apply(lambda x: len(x.split(",")))

# %%
df_recent.head()
# Out:
#                                               description host_is_superhost  \
# id
# 155305  <b>The space</b><br />Private cottage located ...                 t
# 156926  This is a top bunk in the mixed dorm room<br /...                 t
# 209068  Located in one of Asheville's oldest historic ...                 f
# 259576  Hello! We are a small community of like-minded...                 t
# 295496  <b>The space</b><br />Welcome to "Fern Street ...                 f
#
#        host_has_profile_pic host_identity_verified          property_type  \
# id
# 155305                    t                      t      Entire guesthouse
# 156926                    t                      t  Shared room in hostel
# 209068                    t                      t     Entire guest suite
# 259576                    t                      t       Entire apartment
# 295496                    t                      t       Entire apartment
#
#               room_type  accommodates  bathrooms  bedrooms  beds  \
# id
# 155305  Entire home/apt             2        1.0       1.0   1.0
# 156926      Shared room             1        2.5       1.0   6.0
# 209068  Entire home/apt             4        1.0       1.0   2.0
# 259576  Entire home/apt             2        1.0       1.0   1.0
# 295496  Entire home/apt             2        1.0       1.0   0.0
#
#                                                 amenities  price  \
# id
# 155305  ["Hot water", "Free street parking", "Refriger...   92.0
# 156926  ["Air conditioning", "Hot water", "Heating", "...   30.0
# 209068  ["Hot water", "Dryer", "Refrigerator", "Hair d...  134.0
# 259576  ["Hot water", "Dryer", "Ceiling fan", "Refrige...   71.0
# 295496  ["Patio or balcony", "Air conditioning", "Bed ...   50.0
#
#         number_of_reviews instant_bookable   location state last_review_time  \
# id
# 155305                275                t  Asheville    NC           4 days
# 156926                290                t  Asheville    NC           7 days
# 209068                 56                f  Asheville    NC          44 days
# 259576                538                f  Asheville    NC           8 days
# 295496                 32                f  Asheville    NC          29 days
#
#         number_of_amenities
# id
# 155305                   25
# 156926                   13
# 209068                   31
# 259576                   30
# 295496                   18

# %%
df_recent['amenities'] = df_recent['amenities'].str.lower()

# %%
df_recent = df_recent.drop(['hot water'], axis=1)

# %%
df_recent['hot_water'] = df_recent['amenities'].str.contains('hot water')

# %%
df_recent['air_conditioning'] = df_recent['amenities'].str.contains('air conditioning')

# %%
df_recent['parking'] = df_recent['amenities'].str.contains('parking')

# %%
df_recent['refrigerator'] = df_recent['amenities'].str.contains('refrigerator')
df_recent['patio_balcony'] = df_recent['amenities'].str.contains('patio')
df_recent['wifi'] = df_recent['amenities'].str.contains('wifi')
df_recent['breakfast'] = df_recent['amenities'].str.contains('breakfast')
df_recent['hair_dryer'] = df_recent['amenities'].str.contains('hair dryer')

# %%
df_recent['waterfront'] = df_recent['amenities'].str.contains('waterfront')
df_recent['workspace'] = df_recent['amenities'].str.contains('workspace')
df_recent['kitchen'] = df_recent['amenities'].str.contains('kitchen')
df_recent['fireplace'] = df_recent['amenities'].str.contains('fireplace')
df_recent['tv'] = df_recent['amenities'].str.contains('tv')

# %%
df_recent['clothes_dryer'] = df_recent['amenities'].str.contains('dryer')

# %%
df_recent.head(10)
# Out:
#                                               description host_is_superhost  \
# id
# 155305  <b>The space</b><br />Private cottage located ...                 t
# 156926  This is a top bunk in the mixed dorm room<br /...                 t
# 209068  Located in one of Asheville's oldest historic ...                 f
# 259576  Hello! We are a small community of like-minded...                 t
# 295496  <b>The space</b><br />Welcome to "Fern Street ...                 f
# 353092  Sweet homestay space has private entrance, sma...                 t
# 427497  Escape to our beautifully furnished luxurious ...                 f
# 436476  ***We are taking extra steps to make sure our ...                 t
# 483384  The artist/owner built cottage is a quiet sanc...                 t
# 495111  Private room. King bed. Private full bathroom....                 t
#
#        host_has_profile_pic host_identity_verified          property_type  \
# id
# 155305                    t                      t      Entire guesthouse
# 156926                    t                      t  Shared room in hostel
# 209068                    t                      t     Entire guest suite
# 259576                    t                      t       Entire apartment
# 295496                    t                      t       Entire apartment
# 353092                    t                      t     Entire guest suite
# 427497                    t                      f     Entire guest suite
# 436476                    t                      t     Entire guest suite
# 483384                    t                      t         Entire cottage
# 495111                    t                      t  Private room in house
#
#               room_type  accommodates  bathrooms  bedrooms  beds  \
# id
# 155305  Entire home/apt             2        1.0       1.0   1.0
# 156926      Shared room             1        2.5       1.0   6.0
# 209068  Entire home/apt             4        1.0       1.0   2.0
# 259576  Entire home/apt             2        1.0       1.0   1.0
# 295496  Entire home/apt             2        1.0       1.0   0.0
# 353092  Entire home/apt             4        1.0       1.0   3.0
# 427497  Entire home/apt             2        1.0       1.0   1.0
# 436476  Entire home/apt             3        1.5       1.0   1.0
# 483384  Entire home/apt             3        1.0       1.0   1.0
# 495111     Private room             2        1.0       NaN   1.0
#
#                                                 amenities  price  \
# id
# 155305  ["hot water", "free street parking", "refriger...   92.0
# 156926  ["air conditioning", "hot water", "heating", "...   30.0
# 209068  ["hot water", "dryer", "refrigerator", "hair d...  134.0
# 259576  ["hot water", "dryer", "ceiling fan", "refrige...   71.0
# 295496  ["patio or balcony", "air conditioning", "bed ...   50.0
# 353092  ["hot water", "bed linens", "dryer", "shower g...   78.0
# 427497  ["hot water", "dryer", "host greets you", "hai...  125.0
# 436476  ["hot water", "bed linens", "dryer", "shower g...  114.0
# 483384  ["bedroom comforts", "air conditioning", "bath...  133.0
# 495111  ["hot water", "bed linens", "conditioner", "la...   93.0
#
#         number_of_reviews instant_bookable   location state last_review_time  \
# id
# 155305                275                t  Asheville    NC           4 days
# 156926                290                t  Asheville    NC           7 days
# 209068                 56                f  Asheville    NC          44 days
# 259576                538                f  Asheville    NC           8 days
# 295496                 32                f  Asheville    NC          29 days
# 353092                500                f  Asheville    NC          12 days
# 427497                 41                f  Asheville    NC          13 days
# 436476                297                t  Asheville    NC           8 days
# 483384                479                t  Asheville    NC           8 days
# 495111                344                t  Asheville    NC           6 days
#
#         number_of_amenities  hot_water  air_conditioning  parking  \
# id
# 155305                   25       True              True     True
# 156926                   13       True              True     True
# 209068                   31       True              True     True
# 259576                   30       True              True     True
# 295496                   18      False              True     True
# 353092                   29       True              True     True
# 427497                   23       True              True     True
# 436476                   42       True              True     True
# 483384                   19      False              True     True
# 495111                   23       True              True     True
#
#         refrigerator  patio_balcony  wifi  breakfast  hair_dryer  waterfront  \
# id
# 155305          True           True  True      False        True       False
# 156926         False          False  True      False       False       False
# 209068          True           True  True      False        True       False
# 259576          True           True  True      False        True       False
# 295496          True           True  True      False       False       False
# 353092          True          False  True      False        True       False
# 427497         False          False  True      False        True       False
# 436476          True           True  True      False        True       False
# 483384         False          False  True      False        True       False
# 495111         False           True  True      False        True       False
#
#         workspace  kitchen  fireplace     tv  clothes_dryer
# id
# 155305       True     True      False  False           True
# 156926      False    False      False  False          False
# 209068       True     True      False   True           True
# 259576       True     True      False   True           True
# 295496      False     True      False   True          False
# 353092       True    False      False  False           True
# 427497       True     True       True   True           True
# 436476       True     True      False   True           True
# 483384      False     True      False   True           True
# 495111       True    False      False  False           True

# %%
df_recent['waterfront'].value_counts()
# Out:
# False    62542
# True      1224
# Name: waterfront, dtype: int64

# %%
def booleanize(column):
    for i in range(len(column)):
        df_recent[column].iloc[i] = bool(strtobool(df_recent[column].iloc[i]))
    return column

# %%
booleanize('instant_bookable')
# Out:
# 'instant_bookable'

# %%
df_recent.head()
# Out:
#                                               description host_is_superhost  \
# id
# 155305  <b>The space</b><br />Private cottage located ...              True
# 156926  This is a top bunk in the mixed dorm room<br /...              True
# 209068  Located in one of Asheville's oldest historic ...             False
# 259576  Hello! We are a small community of like-minded...              True
# 295496  <b>The space</b><br />Welcome to "Fern Street ...             False
#
#        host_has_profile_pic host_identity_verified          property_type  \
# id
# 155305                 True                   True      Entire guesthouse
# 156926                 True                   True  Shared room in hostel
# 209068                 True                   True     Entire guest suite
# 259576                 True                   True       Entire apartment
# 295496                 True                   True       Entire apartment
#
#               room_type  accommodates  bathrooms  bedrooms  beds  \
# id
# 155305  Entire home/apt             2        1.0       1.0   1.0
# 156926      Shared room             1        2.5       1.0   6.0
# 209068  Entire home/apt             4        1.0       1.0   2.0
# 259576  Entire home/apt             2        1.0       1.0   1.0
# 295496  Entire home/apt             2        1.0       1.0   0.0
#
#                                                 amenities  price  \
# id
# 155305  ["hot water", "free street parking", "refriger...   92.0
# 156926  ["air conditioning", "hot water", "heating", "...   30.0
# 209068  ["hot water", "dryer", "refrigerator", "hair d...  134.0
# 259576  ["hot water", "dryer", "ceiling fan", "refrige...   71.0
# 295496  ["patio or balcony", "air conditioning", "bed ...   50.0
#
#         number_of_reviews instant_bookable   location state last_review_time  \
# id
# 155305                275             True  Asheville    NC           4 days
# 156926                290             True  Asheville    NC           7 days
# 209068                 56            False  Asheville    NC          44 days
# 259576                538            False  Asheville    NC           8 days
# 295496                 32            False  Asheville    NC          29 days
#
#         number_of_amenities  hot_water  air_conditioning  parking  \
# id
# 155305                   25       True              True     True
# 156926                   13       True              True     True
# 209068                   31       True              True     True
# 259576                   30       True              True     True
# 295496                   18      False              True     True
#
#         refrigerator  patio_balcony  wifi  breakfast  hair_dryer  waterfront  \
# id
# 155305          True           True  True      False        True       False
# 156926         False          False  True      False       False       False
# 209068          True           True  True      False        True       False
# 259576          True           True  True      False        True       False
# 295496          True           True  True      False       False       False
#
#         workspace  kitchen  fireplace     tv  clothes_dryer
# id
# 155305       True     True      False  False           True
# 156926      False    False      False  False          False
# 209068       True     True      False   True           True
# 259576       True     True      False   True           True
# 295496      False     True      False   True          False

# %%
df_recent.describe()
# Out:
#        accommodates     bathrooms      bedrooms          beds         price  \
# count  63766.000000  63766.000000  57074.000000  63518.000000  63766.000000
# mean       4.435326      1.437529      1.818341      2.399855    161.921363
# std        2.928230      0.812983      1.132432      1.944385    206.087422
# min        1.000000      0.000000      1.000000      0.000000     10.000000
# 25%        2.000000      1.000000      1.000000      1.000000     75.000000
# 50%        4.000000      1.000000      1.000000      2.000000    112.000000
# 75%        6.000000      2.000000      2.000000      3.000000    182.000000
# max       16.000000     17.000000     21.000000     44.000000  14500.000000
#
#        number_of_reviews            last_review_time  number_of_amenities
# count       63766.000000                       63766         63766.000000
# mean           67.944563  27 days 17:17:06.264780604            29.492990
# std            86.827637  22 days 16:32:58.657953824             8.666891
# min             1.000000             0 days 00:00:00             1.000000
# 25%            10.000000            10 days 00:00:00            23.000000
# 50%            35.000000            20 days 00:00:00            30.000000
# 75%            94.000000            40 days 00:00:00            35.000000
# max           985.000000            90 days 00:00:00            76.000000

# %%
df_recent.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 63766 entries, 155305 to 46033762
# Data columns (total 32 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   description             63131 non-null  object
#  1   host_is_superhost       63760 non-null  object
#  2   host_has_profile_pic    63760 non-null  object
#  3   host_identity_verified  63760 non-null  object
#  4   property_type           63766 non-null  object
#  5   room_type               63766 non-null  object
#  6   accommodates            63766 non-null  int64
#  7   bathrooms               63766 non-null  float64
#  8   bedrooms                57074 non-null  float64
#  9   beds                    63518 non-null  float64
#  10  amenities               63766 non-null  object
#  11  price                   63766 non-null  float64
#  12  number_of_reviews       63766 non-null  int64
#  13  instant_bookable        63766 non-null  object
#  14  location                63766 non-null  object
#  15  state                   63766 non-null  object
#  16  last_review_time        63766 non-null  timedelta64[ns]
#  17  number_of_amenities     63766 non-null  int64
#  18  hot_water               63766 non-null  bool
#  19  air_conditioning        63766 non-null  bool
#  20  parking                 63766 non-null  bool
#  21  refrigerator            63766 non-null  bool
#  22  patio_balcony           63766 non-null  bool
#  23  wifi                    63766 non-null  bool
#  24  breakfast               63766 non-null  bool
#  25  hair_dryer              63766 non-null  bool
#  26  waterfront              63766 non-null  bool
#  27  workspace               63766 non-null  bool
#  28  kitchen                 63766 non-null  bool
#  29  fireplace               63766 non-null  bool
#  30  tv                      63766 non-null  bool
#  31  clothes_dryer           63766 non-null  bool
# dtypes: bool(14), float64(4), int64(3), object(10), timedelta64[ns](1)
# memory usage: 12.6+ MB

# %%
bool_columns = ['host_is_superhost', 
                'host_has_profile_pic', 
                'host_identity_verified', 
                'instant_bookable']
df_recent[bool_columns] = df_recent[bool_columns].astype(bool)

# %%
df_recent.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 63766 entries, 155305 to 46033762
# Data columns (total 32 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   description             63131 non-null  object
#  1   host_is_superhost       63766 non-null  bool
#  2   host_has_profile_pic    63766 non-null  bool
#  3   host_identity_verified  63766 non-null  bool
#  4   property_type           63766 non-null  object
#  5   room_type               63766 non-null  object
#  6   accommodates            63766 non-null  int64
#  7   bathrooms               63766 non-null  float64
#  8   bedrooms                57074 non-null  float64
#  9   beds                    63518 non-null  float64
#  10  amenities               63766 non-null  object
#  11  price                   63766 non-null  float64
#  12  number_of_reviews       63766 non-null  int64
#  13  instant_bookable        63766 non-null  bool
#  14  location                63766 non-null  object
#  15  state                   63766 non-null  object
#  16  last_review_time        63766 non-null  timedelta64[ns]
#  17  number_of_amenities     63766 non-null  int64
#  18  hot_water               63766 non-null  bool
#  19  air_conditioning        63766 non-null  bool
#  20  parking                 63766 non-null  bool
#  21  refrigerator            63766 non-null  bool
#  22  patio_balcony           63766 non-null  bool
#  23  wifi                    63766 non-null  bool
#  24  breakfast               63766 non-null  bool
#  25  hair_dryer              63766 non-null  bool
#  26  waterfront              63766 non-null  bool
#  27  workspace               63766 non-null  bool
#  28  kitchen                 63766 non-null  bool
#  29  fireplace               63766 non-null  bool
#  30  tv                      63766 non-null  bool
#  31  clothes_dryer           63766 non-null  bool
# dtypes: bool(18), float64(4), int64(3), object(6), timedelta64[ns](1)
# memory usage: 10.9+ MB

# %%
df_recent.head(10)
# Out:
#                                               description  host_is_superhost  \
# id
# 155305  <b>The space</b><br />Private cottage located ...               True
# 156926  This is a top bunk in the mixed dorm room<br /...               True
# 209068  Located in one of Asheville's oldest historic ...              False
# 259576  Hello! We are a small community of like-minded...               True
# 295496  <b>The space</b><br />Welcome to "Fern Street ...              False
# 353092  Sweet homestay space has private entrance, sma...               True
# 427497  Escape to our beautifully furnished luxurious ...              False
# 436476  ***We are taking extra steps to make sure our ...               True
# 483384  The artist/owner built cottage is a quiet sanc...               True
# 495111  Private room. King bed. Private full bathroom....               True
#
#         host_has_profile_pic  host_identity_verified          property_type  \
# id
# 155305                  True                    True      Entire guesthouse
# 156926                  True                    True  Shared room in hostel
# 209068                  True                    True     Entire guest suite
# 259576                  True                    True       Entire apartment
# 295496                  True                    True       Entire apartment
# 353092                  True                    True     Entire guest suite
# 427497                  True                   False     Entire guest suite
# 436476                  True                    True     Entire guest suite
# 483384                  True                    True         Entire cottage
# 495111                  True                    True  Private room in house
#
#               room_type  accommodates  bathrooms  bedrooms  beds  \
# id
# 155305  Entire home/apt             2        1.0       1.0   1.0
# 156926      Shared room             1        2.5       1.0   6.0
# 209068  Entire home/apt             4        1.0       1.0   2.0
# 259576  Entire home/apt             2        1.0       1.0   1.0
# 295496  Entire home/apt             2        1.0       1.0   0.0
# 353092  Entire home/apt             4        1.0       1.0   3.0
# 427497  Entire home/apt             2        1.0       1.0   1.0
# 436476  Entire home/apt             3        1.5       1.0   1.0
# 483384  Entire home/apt             3        1.0       1.0   1.0
# 495111     Private room             2        1.0       NaN   1.0
#
#                                                 amenities  price  \
# id
# 155305  ["hot water", "free street parking", "refriger...   92.0
# 156926  ["air conditioning", "hot water", "heating", "...   30.0
# 209068  ["hot water", "dryer", "refrigerator", "hair d...  134.0
# 259576  ["hot water", "dryer", "ceiling fan", "refrige...   71.0
# 295496  ["patio or balcony", "air conditioning", "bed ...   50.0
# 353092  ["hot water", "bed linens", "dryer", "shower g...   78.0
# 427497  ["hot water", "dryer", "host greets you", "hai...  125.0
# 436476  ["hot water", "bed linens", "dryer", "shower g...  114.0
# 483384  ["bedroom comforts", "air conditioning", "bath...  133.0
# 495111  ["hot water", "bed linens", "conditioner", "la...   93.0
#
#         number_of_reviews  instant_bookable   location state last_review_time  \
# id
# 155305                275              True  Asheville    NC           4 days
# 156926                290              True  Asheville    NC           7 days
# 209068                 56             False  Asheville    NC          44 days
# 259576                538             False  Asheville    NC           8 days
# 295496                 32             False  Asheville    NC          29 days
# 353092                500             False  Asheville    NC          12 days
# 427497                 41             False  Asheville    NC          13 days
# 436476                297              True  Asheville    NC           8 days
# 483384                479              True  Asheville    NC           8 days
# 495111                344              True  Asheville    NC           6 days
#
#         number_of_amenities  hot_water  air_conditioning  parking  \
# id
# 155305                   25       True              True     True
# 156926                   13       True              True     True
# 209068                   31       True              True     True
# 259576                   30       True              True     True
# 295496                   18      False              True     True
# 353092                   29       True              True     True
# 427497                   23       True              True     True
# 436476                   42       True              True     True
# 483384                   19      False              True     True
# 495111                   23       True              True     True
#
#         refrigerator  patio_balcony  wifi  breakfast  hair_dryer  waterfront  \
# id
# 155305          True           True  True      False        True       False
# 156926         False          False  True      False       False       False
# 209068          True           True  True      False        True       False
# 259576          True           True  True      False        True       False
# 295496          True           True  True      False       False       False
# 353092          True          False  True      False        True       False
# 427497         False          False  True      False        True       False
# 436476          True           True  True      False        True       False
# 483384         False          False  True      False        True       False
# 495111         False           True  True      False        True       False
#
#         workspace  kitchen  fireplace     tv  clothes_dryer
# id
# 155305       True     True      False  False           True
# 156926      False    False      False  False          False
# 209068       True     True      False   True           True
# 259576       True     True      False   True           True
# 295496      False     True      False   True          False
# 353092       True    False      False  False           True
# 427497       True     True       True   True           True
# 436476       True     True      False   True           True
# 483384      False     True      False   True           True
# 495111       True    False      False  False           True
